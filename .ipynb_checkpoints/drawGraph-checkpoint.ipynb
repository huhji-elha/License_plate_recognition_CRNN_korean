# %%
import os
import pandas as pd

path = "/.../checkpoint/"
file_list = os.listdir(path)

turn1_2 = pd.read_csv("turn1_2.csv", index_col=False)

# %%
turn_3 = []
for l in file_list :
    if l[0] == '2' :
        turn_3.append(l[3:])

# %%
epoch_loss = []
for w in turn_3 :
    epoch_loss.append([w[10:12], float(w[14:-5])])

# %%
w = pd.DataFrame(epoch_loss)
w.columns = ['epoch', 'loss']
w['turn'] = "third-img 700k"
w2 = w.sort_values(by="turn")
turn1_3 = pd.concat([turn1_2,w2])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid')

# %%
plt.figure(figsize=(12,6))
palette = sns.color_palette("mako_r", 6)
sns.lineplot(x='epoch', y='loss', style='turn',hue='turn',data=w4, markers=True)

# %%
plt.figure(figsize=(12,6))
palette = sns.color_palette("mako_r", 6)
sns.lineplot(x='epoch', y='loss', style='turn',hue='turn',data=w5, markers=True)

# %%
plt.figure(figsize=(12,6))
plt.plot(w['epoch'],w['loss'],'gs--')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['turn \nthird-img 700k'])
